# %% [markdown]
# <a href="https://colab.research.google.com/github/twital/006975/blob/master/%EC%9D%B4%EA%B2%8C%EB%AA%A8~%EC%A7%80%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
gdown.download('https://www.data4library.kr/openDataL','제주 탐라도서관 장서 대출목록 (2023년 08월).csv',quiet=False)
# Out:
# Downloading...
# From: https://www.data4library.kr/openDataL
# To: /content/제주 탐라도서관 장서 대출목록 (2023년 08월).csv
# 37.6kB [00:00, 18.1MB/s]
# '제주 탐라도서관 장서 대출목록 (2023년 08월).csv'

# %%
import pandas as pd
df = pd.read_csv('제주 탐라도서관 장서 대출목록 (2023년 08월).csv', error_bad_lines=False, low_memory=False)
# Out:
# <ipython-input-17-d716eb59f18d>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('제주 탐라도서관 장서 대출목록 (2023년 08월).csv', error_bad_lines=False, low_memory=False)
# Skipping line 13: expected 1 fields, saw 2
# Skipping line 162: expected 1 fields, saw 2
# Skipping line 167: expected 1 fields, saw 2
# Skipping line 168: expected 1 fields, saw 2
# Skipping line 171: expected 1 fields, saw 2
# Skipping line 227: expected 1 fields, saw 2
# Skipping line 231: expected 1 fields, saw 2
# Skipping line 259: expected 1 fields, saw 7
# Skipping line 260: expected 1 fields, saw 3
# Skipping line 261: expected 1 fields, saw 2
# Skipping line 262: expected 1 fields, saw 5
# Skipping line 268: expected 1 fields, saw 2
# Skipping line 269: expected 1 fields, saw 2
# Skipping line 276: expected 1 fields, saw 2
# Skipping line 277: expected 1 fields, saw 2
# ...

# %%
# Out:
#                                      <!DOCTYPE html>
# 0                                   <html lang="ko">
# 1                                             <head>
# 2  \t<meta http-equiv="content-type" content="tex...
# 3      <meta http-equiv="X-UA-Compatible" content...
# 4      <meta http-equiv="Content-Security-Policy"...
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 9 (	) missing from current font.
#   plt.savefig(
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
# ...

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(_df_0, *['<!DOCTYPE html>'], **{})
chart
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 9 (	) missing from current font.
#   plt.savefig(
# <img src="...

# %% [markdown]
# ## ***D-391***

# %%
d={"name" : "241003250123200221"}
print(d['name'])
# Out:
# 241003250123200221

# %%
import json
d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
# Out:
# {"name": "241003250123200221"}

# %%
type(d_str)
# Out:
# str

# %%
d2=json.loads(d_str)
print(d2['name'])
# Out:
# 241003250123200221

# %%
d3 = json.loads('{"name":"감자", "school":"MX", "class":"특"}')

# %% [markdown]
# #**9/15**

# %% [markdown]
# 4099b071572214718b4dd995cdf99f8bda2ec31ceab77efc21e3bf727036b62a

# %%
x_str = """
<book>
  <name>이민혁</name>
  <troop>5사단</troop>
  <date>241003</date>
</book>
"""

# %%
import xml.etree.ElementTree as et
x = et.fromstring(x_str)

# %%
print(type(x))
# Out:
# <class 'xml.etree.ElementTree.Element'>

# %%
print(x.tag)
# Out:
# book

# %%
x_child = list(x)
print(x_child)
# Out:
# [<Element 'name' at 0x7f1195fc8630>, <Element 'school' at 0x7f1195fc8680>, <Element 'date' at 0x7f1195fc86d0>]

# %%
name, troop, date = x_child
print(name.text)
print(troop.text)
print(date.text)
# Out:
# 이민혁
# 5사단
# 241003

# %%
name = x.findtext('name')
troop = x.findtext('troop')
date = x.findtext('date')
print(name)
print(troop)
print(date)
# Out:
# 이민혁
# 5사단
# 241003

# %%
import requests
a = '몬스타엑스'
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query={}'
r=requests.get(url.format(a))

# %%
print(r.text)
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="몬스타엑스 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'몬스타엑스'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'몬스타엑스'의 네이버 통합검색 결과입니다."> <title>몬스타엑스 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.psta
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
prd_link = soup.find('a', attrs={'class':'area_card'})
print(prd_link)
# Out:
# <a class="area_card" href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=2656437&amp;qvt=0&amp;query=%EC%85%94%EB%88%84" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*u.mmember&amp;r=1&amp;i=1800000D_000000288893&amp;u=' + urlencode(this.href));"> <div class="area_link_box"> <div class="thumb"> <img alt="셔누 이미지" height="84" src="https://search.pstatic.net/common?type=n&amp;size=150x168&amp;quality=100&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fpeople%2FprofileImg%2F4779427a-0211-403f-875f-fad85fde9680.jpg" width="75"/> </div> <div class="title_box"> <strong class="name type_ell_2">셔누</strong> </div> </div> </a>

# %%
print(prd_link['href'])
# Out:
# ?where=nexearch&sm=tab_etc&mra=bjky&pkid=1&os=2656437&qvt=0&query=%EC%85%94%EB%88%84

# %%
url = 'https://search.naver.com/search.naver'+prd_link['href']
r=requests.get(url)

# %%
print(r.text)
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="셔누 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'셔누'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'셔누'의 네이버 통합검색 결과입니다."> <title>셔누 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/ssta
# ...

# %% [markdown]
# # ***9/22***

# %%
import requests
isbn = '9788934940951'
url = 'https://www.yes24.com/Product/Search?domain=BOOK&query={}'
r=requests.get(url.format(isbn))

# %%
print (r. text)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
prd_link = soup.find('a', attrs={'class': 'gd_name'})
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/122433573" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9788934940951', '122433573', '0');">스티커 도깨비 무지 막지</a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/122433573

# %%
url = 'https://www.yes24.com'+prd_link['href']
r=requests.get(url)

# %%
print(r. text)

# %%
soup = BeautifulSoup(r.text, 'html.parser')
pro_detail = soup.find( 'div', attrs={'id': 'infoset_specific'})
#pro_detail_2 = soupo.find('table', attrs={'class':'tb_nor tb_vertical '})
print(pro_detail)

# %%
prd_tr_list = pro_detail.find_all('tr')
print(prd_tr_list)

# %%
# 쪽, 무게, 크기 가져오기
for tr in prd_tr_list:
  if tr.find('th').get_text() == '쪽수, 무게, 크기':
    page_td = tr.find('td').get_text()
    break

# %%
print(page_td)
# Out:
# 88쪽 | 324g | 167*237*10mm

# %%
 print(page_td.split()[0])
# Out:
# 88쪽

# %%
#### 위의 코드를 사용자 정의 함수로 만들기 ####

def get_page_cnt(isbn):
  url = 'https://www.yes24.com/Product/Search?domain=BOOK&query={}'

  # URL에 isbn을 넣어 HTML 가져옴
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser')   #파싱

  # 검색 결과에서 해당 도서 선택
  prd_info = soup.find('a', attrs={'class' : 'gd_name'})

  # 도서 상세 페이지 가져오기
  url = 'http://www.yes24.com'+prd_info['href']
  r= requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')

  # 품목정보 <div>를 선택
  prd_detail = soup.find('div', attrs={'id': 'infoset_specific'})

  # 테이블에 있는 <tr> 태그 가져오기
  prd_tr_list = prd_detail.find_all('tr')

  # 쪽수가 들어 있는 <th>를 찾아 <tO에 담긴 값을 반환
  for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
      return tr.find('td').get_text().split()[0]
  return ''

# %%
get_page_cnt(9788934940951)
# Out:
# '88쪽'

# %%
# 20대가 가장 좋아하는 도서 찾기 -> API사용하기 소스코드에서 가져오기

import requests
url=

r=requests.get(url)

data=r.json()

books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# %%
import pandas as pd
books_df = pd.DataFrame(books)
books_df

# %%
# jason 파일로 저장하기
books_df.to_json('20s_best_book.json')

# %%
top5_book = books_df.head(5)
top5_book

# %%
# isbn13의 값을 전달하는 사용자 정의 함수 만들기
def get_page_cnt2(row):
  isbn = row['isbn13']
  return get_page_cnt(isbn)

# %%
page_count = top5_book.apply(get_page_cnt2, axis=1)     #axis의 값이 '0'이면 행, '1'이면 열에 적용됨
print(page_count)

# %%
# page_count 시리즈 객체 이름 만들어주기
page_count.name = page_count'
print(page_count)

# %%
# 데이터프레임과 시리즈 합치기 : merge()함수
top5_with_page_count = pd.merge(top5_book, page_count, left_index=True, right_index=True)

top5_with_page_count
